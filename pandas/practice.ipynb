# %% [markdown]
# # Pandas Practice

# %%
import pandas as pd

# %% [markdown]
# **Level: 01 Easy**

# %% [markdown]
# Create a Pandas Series from a Python list.

# %%
lst = [12,34,'Harsh','9905011725',67]

df = pd.Series(lst)
df
# Out:
# 0            12
# 1            34
# 2         Harsh
# 3    9905011725
# 4            67
# dtype: object

# %% [markdown]
# Create a DataFrame using a dictionary containing lists.

# %%
data = {
    'Name':['Harsh Kumar','Aashiish Kumar','Shalini Kimari','Raushan Kumar','Amrita Kumari'],
    'Age':[19,17,22,25,24],
    'Study':[True,True,True,True,False]
}

df = pd.DataFrame(data)
df
# Out:
#              Name  Age  Study
# 0     Harsh Kumar   19   True
# 1  Aashiish Kumar   17   True
# 2  Shalini Kimari   22   True
# 3   Raushan Kumar   25   True
# 4   Amrita Kumari   24  False

# %% [markdown]
# Create a DataFrame from a list of tuples.

# %%
data = [('Harsh',19),('Aashish',20),('Shalini',24)]

df = pd.DataFrame(data,columns=['Name','Age'])
df
# Out:
#       Name  Age
# 0    Harsh   19
# 1  Aashish   20
# 2  Shalini   24

# %% [markdown]
# Load a CSV file into a DataFrame.

# %%
sale_df = pd.read_csv('sales_data_sample.csv',encoding='latin1')
df.head(10)
df.tail(5)
# Out:
#            Name  Age  Roll No Enrollment No
# 3    Ravi kumar   22      154  A45349524154
# 4    Sparsh Avi   19      155  A45349524155
# 5   Rishi kumar   23      156  A45349524156
# 6   Anmol kumar   18      157  A45349524157
# 7  Aditya kumar   19      158  A45349524158

# %% [markdown]
# Print column names of a DataFrame.

# %%
print(sale_df.columns)
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# Get total rows and columns in a DataFrame.

# %%
print(sale_df.shape)   # (rows, columns)
# Out:
# (2823, 25)

# %% [markdown]
# Check data types of all columns.

# %%
# df.info()
sale_df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %% [markdown]
# Convert a DataFrame to a NumPy array.

# %%
arr = df.to_numpy()
arr
# Out:
# array([[10107, 30, 95.7, ..., 'Yu', 'Kwai', 'Small'],
#        [10121, 34, 81.35, ..., 'Henriot', 'Paul', 'Small'],
#        [10134, 41, 94.74, ..., 'Da Cunha', 'Daniel', 'Medium'],
#        ...,
#        [10386, 43, 100.0, ..., 'Freyre', 'Diego', 'Medium'],
#        [10397, 34, 62.24, ..., 'Roulet', 'Annette', 'Small'],
#        [10414, 47, 65.52, ..., 'Yoshido', 'Juri', 'Medium']],
#       shape=(2823, 25), dtype=object)

# %% [markdown]
# **Level : 02 Medium**

# %% [markdown]
# Select a single column using both bracket and dot notation.

# %%
students = {
    "Name": ['Mantosh kumar','sumant kumar','Prashant kuamr',None,'Sparsh Avi','Rishi kumar','Anmol kumar','Aditya kumar'],
    "Age": [18,20,21,22,19,23,None,19],
    "Roll No":[151,152,153,154,None,156,157,158]

}
df = pd.DataFrame(students)

# %%
df['Age'] # bracket
df.Age # dot notation
# Out:
# 0    18.0
# 1    20.0
# 2    21.0
# 3    22.0
# 4    19.0
# 5    23.0
# 6     NaN
# 7    19.0
# Name: Age, dtype: float64

# %%
df.loc[0]
df.iloc[1]
df.loc[2:5,['Age','Roll No']]
df.iloc[0:2,1:3]
# Out:
#     Age  Roll No
# 0  18.0    151.0
# 1  20.0    152.0

# %% [markdown]
# Filter rows where a column value is greater than a given number.

# %%
num = 18
dff = df.sort_values(by='Age')
dff[dff['Age']>num]
# Out:
#              Name   Age  Roll No
# 4      Sparsh Avi  19.0      NaN
# 7    Aditya kumar  19.0    158.0
# 1    sumant kumar  20.0    152.0
# 2  Prashant kuamr  21.0    153.0
# 3            None  22.0    154.0
# 5     Rishi kumar  23.0    156.0

# %% [markdown]
# Filter rows using multiple conditions (AND / OR).

# %%
df[(df['Roll No']>156)  & (df['Age']>18)] # And

df[(df['Roll No']>155)  | (df['Age']>18)] # And
# Out:
#              Name   Age  Roll No
# 1    sumant kumar  20.0    152.0
# 2  Prashant kuamr  21.0    153.0
# 3            None  22.0    154.0
# 4      Sparsh Avi  19.0      NaN
# 5     Rishi kumar  23.0    156.0
# 6     Anmol kumar   NaN    157.0
# 7    Aditya kumar  19.0    158.0

# %% [markdown]
# Add a new column calculated from existing columns

# %%
df['New Roll No'] = df['Roll No']

# %% [markdown]
# Rename one or more columns.

# %%
df.rename(columns={'New Roll No':'Enrollment No'},inplace=True)
df['Enrollment No'] = 'A45349524' + df['Enrollment No'].astype(str)

df
# Out:
#              Name        Age     Roll No                Enrollment No
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3            None  22.000000  154.000000               A45349524154.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0

# %% [markdown]
# Drop a column permanently from a DataFrame.

# %%
# df.drop(columns=[(3, 'Name')],inplace=True)
df
# Out:
#              Name        Age     Roll No                Enrollment No
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3      Sanju Baba  22.000000  154.000000               A45349524154.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0

# %% [markdown]
# Drop rows containing missing values.

# %%
sale_df.dropna(inplace=True)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10   2/20/2004 0:00  Shipped       1         2     2004  ...
# 21  12/17/2004 0:00  Shipped       4        12     2004  ...
# 40   7/19/2004 0:00  Shipped       3         7     2004  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2       CITY  \
# 10                        636 St Kilda Road       Level 3  Melbourne
# 21  Monitor Money Building, 815 Pacific Hwy       Level 6  Chatswood
# 40  Monitor Money Building, 815 Pacific Hwy       Level 6  Chatswood
#
#        STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# ...

# %% [markdown]
# Fill missing values using mean / median.

# %%
df[['Age','Roll No']] = df[['Age','Roll No']].fillna(df[['Age','Roll No']].mean())
df['Name'].fillna('Sanju Baba',inplace=True)
df
# Out:
#              Name        Age     Roll No                Enrollment No
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3     Harsh Kumar  22.000000  154.000000               A45349524154.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0

# %% [markdown]
# Replace specific values in a column.

# %%
df['Name'].replace('Harsh Kumar','Sanju Baba',inplace=True)
df
# Out:
#              Name        Age     Roll No                Enrollment No  \
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3      Sanju Baba  22.000000  154.000000               A45349524154.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0
#
#     (3, Name)
# 0  Sanju Baba
# 1  Sanju Baba
# 2  Sanju Baba
# 3  Sanju Baba
# 4  Sanju Baba
# 5  Sanju Baba
# 6  Sanju Baba
# 7  Sanju Baba

# %% [markdown]
# **Level : 03 Advance**

# %% [markdown]
#  Sort a DataFrame by one column in ascending order

# %%
df.sort_values(by=['Age'],ascending=True)
# Out:
#              Name        Age     Roll No                Enrollment No
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3      Sanju Baba  22.000000  154.000000               A45349524154.0
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0

# %% [markdown]
# Sort by multiple columns with different orders

# %%
df.sort_values(by=['Age','Roll No'],ascending=[True,False])
# Out:
#              Name        Age     Roll No                Enrollment No
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3      Sanju Baba  22.000000  154.000000               A45349524154.0
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0

# %% [markdown]
# Group by a column and calculate sum

# %%
df.groupby('Name')['Roll No'].sum()
# Out:
# Name
# Aditya kumar      158.000000
# Anmol kumar       157.000000
# Mantosh kumar     151.000000
# Prashant kuamr    153.000000
# Rishi kumar       156.000000
# Sanju Baba        154.000000
# Sparsh Avi        154.428571
# sumant kumar      152.000000
# Name: Roll No, dtype: float64

# %% [markdown]
# Group by multiple columns and calculate mean

# %%
df.groupby(['Name','Age'])['Roll No'].sum()
df
# Out:
#              Name        Age     Roll No                Enrollment No
# 0   Mantosh kumar  18.000000  151.000000               A45349524151.0
# 1    sumant kumar  20.000000  152.000000               A45349524152.0
# 2  Prashant kuamr  21.000000  153.000000               A45349524153.0
# 3      Sanju Baba  22.000000  154.000000               A45349524154.0
# 4      Sparsh Avi  19.000000  154.428571  A45349524154.42857142857142
# 5     Rishi kumar  23.000000  156.000000               A45349524156.0
# 6     Anmol kumar  20.285714  157.000000               A45349524157.0
# 7    Aditya kumar  19.000000  158.000000               A45349524158.0

# %% [markdown]
# Apply multiple aggregations

# %%
df.groupby('Name')['Roll No'].agg(['mean','sum','median'])
# Out:
#                       mean         sum      median
# Name
# Aditya kumar    158.000000  158.000000  158.000000
# Anmol kumar     157.000000  157.000000  157.000000
# Mantosh kumar   151.000000  151.000000  151.000000
# Prashant kuamr  153.000000  153.000000  153.000000
# Rishi kumar     156.000000  156.000000  156.000000
# Sanju Baba      154.000000  154.000000  154.000000
# Sparsh Avi      154.428571  154.428571  154.428571
# sumant kumar    152.000000  152.000000  152.000000

# %% [markdown]
# Merge Two DataFrame

# %%
df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["A", "B", "C"]})
df2 = pd.DataFrame({"ID": [2, 3, 4], "Salary": [50000, 60000, 70000]})

pd.merge(df1, df2, on="ID", how="inner")
# Out:
#    ID Name  Salary
# 0   2    B   50000
# 1   3    C   60000

# %% [markdown]
# Merge using Left and Right joins

# %%
pd.merge(df1,df2, on='ID',how='left')
pd.merge(df1,df2,on='ID',how='right')
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %% [markdown]
# # Conditionals Practice Questions
#
# This notebook contains all practice questions related to conditional statements in Python.

# %% [markdown]
# ## Question 1: Even or Odd Number
# Write a program to find out whether a given number is even or odd.

# %%
# Write a program to find out whether a given number is even or odd.
num = float(input("Enter num:"))
if num %2 == 0:
    print("num is even")
else:
    print("num is odd")

# %% [markdown]
# ## Question 2: Grade Calculator
# Write a program to calculate the grade of a student from his marks from the following scheme:
# - 90 – 100 => Ex
# - 80 – 90 => A
# - 70 – 80 => B
# - 60 – 70 => C
# - 50 – 60 => D
# - <50 => F

# %%
marks = float(input("Enter marks:"))

if marks >= 90 and marks <= 100:
    print("Excellent ")
elif marks >= 80 and marks <= 90:
    print("A grade")
elif marks >= 70 and marks <= 80:
    print("B grade")
elif marks >= 60 and marks <= 70:
    print("C grade")
elif marks >= 50 and marks <= 60:
    print("D grade")
else:
    print("You are fail")
# Out:
# A grade

# %% [markdown]
# ## Question 3: Greatest of Four Numbers
# WAP to find the greatest of four number entered by user

# %%
num1 = int(input("Enter your first number :"))
num2 = int(input("Enter your second number :"))
num3 = int(input("Enter your third number :"))
num4 = int(input("Enter your fourth number :"))

if num1 >= num2 and num1 >= num3 and num1 >= num4:
    print ("The greatest of the four numbers is :", num1)
elif num2 >= num1 and num2 >= num3 and num2 >= num4:
    print ("The greatest of the four numbers is :", num2)
elif  num3 >= num1 and num3 >= num2 and num3 >= num4:
    print("The greatest of the four numbers is :", num3)
else:
    print("The greatest of the four numbers is :",num4)

# %% [markdown]
# ## Question 4: Name in List
# Write a program which finds out whether a given name is present in a list or not.

# %%
name = input("Enter name ensure only first letter is captail:").capitalize()

name_list = ['Harsh','Amit', 'Rahul', 'Navnit','Shali', 'Sakshi', 'kunal', 'Prakash', 'Abhishek']
if name in name_list:
    print(f"{name} is present in name list")
else:
    print(f"{name} is not present in name list")
# Out:
# Ravi is not present in name list

# %% [markdown]
# ## Question 5: Compare Two Numbers
# Write a program to find two number either 'a' is larger or 'b is larger

# %%
a = int(input("Enter your first number:"))
b = int(input("Enter your second number:"))

if a > b:
    print("a is larger")
elif a == b:
    print("Both are equal")
else:
    print("B is larger")
# Out:
# a is larger

# %% [markdown]
# ## Question 6: Positive or Negative
# WAP to find out the number is positive or negative.

# %%
num = float(input("Enter num:"))
if num >=0:
    print("num is positive")
else:
    print("num is negative")

# %% [markdown]
# ## Question 7: Post About Harry
# Write a program to find out whether a given post is talking about "Harry" or not.

# %%
word = input("Enter name:").capitalize()
post = "A post is a message or content shared by Harry on social media online to inform, express ideas, connect with others, or start conversations."

if word in post:
    print(f"given post is talkin about {word}")
else:
    print(f"given post is not talking about {word}")
# Out:
# given post is not talking about Social

# %% [markdown]
# ## Question 8: Spam Detection
# A spam comment is defined as a text containing following keywords: "Make a lot of money", "buy now", "subscribe this", "click this". Write a program to detect these spams.

# %%
text = input("Enter text:").capitalize()
spams = ['make a lot of money', 'buy now', 'subscribe this', 'click this']

if text in spams:
    print("this is spams")
else:
    print("this is not spam")
# Out:
# this is not spam

# %% [markdown]
# ## Question 9: Pass or Fail
# Write a program to find out whether a student has passed or failed if it requires a total of 40% and at least 33% in each subject to pass. Assume 3 subjects and take marks as an input from the user.

# %%
sub1 = float(input("Enter your first subject's mark :"))
sub2 = float(input("Enter your second subject's mark :"))
sub3 = float(input("Enter your third subject's mark :"))

total_marks = sub1 + sub2 + sub3
percentage = (total_marks / 300) * 100
print(percentage)

if (percentage >= 40) and (sub1 >= 33) and (sub2 > 33) and (sub3 > 33):
    print("You have passed the exam")
    print("your percentage is", percentage)
else:
    print("You have failed the exam")
    print("your percentage is", percentage)

# %% [markdown]
# ## Question 10: Username Length
# Write a program to find whether a given username contains less than 10 characters or not.

# %%
username = input("Enter your username:")

if len(username) <= 10:
    print("username less than 10 character")
else:
    print("username is more than 10 character")
